# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split

# %%
import mglearn as mg
X,y=mg.datasets.make_wave(n_samples=40)

# %%
plt.plot(X,y,'o')
plt.ylim(-3,3)
plt.xlabel("feature")
plt.ylabel("Target")
# Out:
# Text(0, 0.5, 'Target')

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)
train_accuracy=[]
test_accuracy=[]

# %%
k_values=range(1,11)
for k in k_values:
    knn=KNeighborsRegressor(k)
    knn.fit(X_train,y_train)
    (train_accuracy.append(knn.score(X_train,y_train)))
    (test_accuracy.append(knn.score(X_test,y_test)))

# %%
print ("train accuracy : \n{}".format({v:n for v,n in zip(k_values,train_accuracy)}))
print ("test accuracy : \n{}".format({v:n for v,n in zip(k_values,test_accuracy)}))
# Out:
# train accuracy :
# {1: 1.0, 2: 0.8482736459820792, 3: 0.8121779007111662, 4: 0.8079772179505501, 5: 0.8086383208237251, 6: 0.80462247008004, 7: 0.7934498878133519, 8: 0.7688756907029876, 9: 0.7602912072759804, 10: 0.7123039435373273}
# test accuracy :
# {1: 0.5962736606042804, 2: 0.7336345185547339, 3: 0.826032699451991, 4: 0.8124684069526248, 5: 0.8228436331071144, 6: 0.7692859504961909, 7: 0.7680460720389333, 8: 0.7593014886400723, 9: 0.7447727010621604, 10: 0.7194152263697428}

# %%
plt.plot(k_values,train_accuracy,label="train accuracy")
plt.plot(k_values,test_accuracy,label="test accuracy")
plt.xlabel("k")
plt.ylabel("Accuracy")
plt.legend()

# %% [markdown]
# Note how the dataset is overfitted for the values of k in range [1,2] and performs much m=better whenk=5
